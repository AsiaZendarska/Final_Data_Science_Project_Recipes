# %% [markdown]
# # Wstęp
# W pierwszej części projektu skupiami się na scrapowaniu danych z różnych stron internetowych z przepisami kulinarnymi. Celem jest zebranie informacji o przepisach takich jak tytuł, składniki, sposób przygotowania, ocena, liczba opinii, czas przygotowania oraz czy przepis jest wegetariański.

# %% [markdown]
# ## Import bibliotek

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup
from time import sleep
import json
import re
from collections import Counter
from wordcloud import WordCloud
import time

colab_start_time = time.time()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp '/content/drive/My Drive/PK-DS-JZTW-colabs/our_functions.py' /content/

# %%
import our_functions

# %%
# W celu monitorowania czasu wykonywania kodu, definiujemy funkcje startu i stopu stopera

# %%writefile our_functions.py

def start_time_meter():
  # Uruchomienie stopera
  print("Rozpoczęcie pomiaru czasu wykonania fragmentu kodu.")
  return time.time()

def stop_time_meter(start_time):
  # Zatrzymanie stopera
  end_time = time.time()

  # Obliczenie czasu wykonania
  execution_time = end_time - start_time

  # Wyświetlenie czasu wykonania
  return print(f"Czas wykonania: {execution_time:.2f} sekundy")

# %%
# Ustawiamy nagłówek dla wszystkich pobrań
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

# %% [markdown]
# ## Scrapowanie pierwszej strony z przepisami (kwestiasmaku.com)

# %%
# Pobieramy url na podstawie kategorii i numeru strony
def get_recipe_page_kwestiasmaku(base_url, category, page_number, include_przepisy_html=True):
    if page_number == 1:
        url = f'{base_url}/{category}' + ('/przepisy.html' if include_przepisy_html else '')
    else:
        url = f'{base_url}/{category}' + ('/przepisy.html' if include_przepisy_html else '') + f'?page={page_number}'
    print(f'Pobieranie URL: {url}')  # Dodano dla debugowania
    content = requests.get(url).text
    # Zwracany jest obiekt BeautifulSoup który zawiera przetworzoną stonę HTML
    return BeautifulSoup(content, 'html.parser')

# Pobieramy szczegółowe informacje o przepisie
def get_recipe_details_kwestiasmaku(recipe_url, category):
    response = requests.get(recipe_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    # znajdowanie tytułu
    title_element = soup.find('h1', {'class': 'przepis page-header'})
    recipe_title = title_element.get_text(strip=True) if title_element else 'Brak tytułu'
    # znajdowanie składników
    ingredients_list = soup.find('div', {'class' : 'field field-name-field-skladniki field-type-text-long field-label-hidden'})
    ingredients = [li.get_text(strip=True) for li in ingredients_list.find_all('li')] if ingredients_list else []
    # znajdowanie oceny
    rating_element = soup.find('span', {'itemprop': 'ratingValue'})
    rating = rating_element.get_text(strip=True) if rating_element else 'Brak oceny'
    # znajdowanie liczby opinii
    opinions = soup.find('span', {'itemprop': 'reviewCount'})
    opinions_count = opinions.get_text(strip=True) if opinions else 'Brak opinii'
    # znajdowanie sposobu przygotowania
    preparation_method_container = soup.find('div', {'class' : 'field field-name-field-przygotowanie field-type-text-long field-label-above'})
    preparation_method = preparation_method_container.get_text(strip=True) if preparation_method_container else 'Brak sposobu przygotowania'

    return {'category': category, 'recipe_title': recipe_title, 'ingredients': ';'.join(ingredients), 'preparation_method': preparation_method, 'rating': rating, 'opinions_count': opinions_count}

# Iterujemy przez określoną liczę stron w danej kategorii, pobierając i zbierając szcegóły przepisów
def get_recipes_data_kwestiasmaku(category, number_of_pages, base_url, include_przepisy_html=True):
    all_recipes = []
    for page_number in range(1, number_of_pages + 1):
        soup = get_recipe_page_kwestiasmaku(base_url, category, page_number, include_przepisy_html)
        recipes = soup.find_all('div', {'class': 'col col-lg-3'})
        for recipe in recipes:
            link_element = recipe.find('a', href=True)
            if link_element:
                recipe_link = 'https://www.kwestiasmaku.com' + link_element['href']
                print(recipe_link)
                details = get_recipe_details_kwestiasmaku(recipe_link, category)
                if details:  # Dodajemy tylko, jeśli udało się pobrać szczegóły
                    all_recipes.append(details)
        print(f'Downloaded data from page {page_number}')
    return all_recipes

# %%
# !ls
# Out:
# drive  our_functions.py  __pycache__  sample_data

# %%
# Ten fragment kodu pobiera dane przepisów z różnych kategorii oraz mierzy czas wykonania każdego z pobrań
start_time = our_functions.start_time_meter()
breakfast_data = our_functions.get_recipes_data_kwestiasmaku('sniadania', 8, 'https://www.kwestiasmaku.com/dania_dla_dwojga', include_przepisy_html=True)
our_functions.stop_time_meter(start_time)
print('-----')
start_time = start_time_meter()
main_dish_data = our_functions.get_recipes_data_kwestiasmaku('dania-obiadowe', 8, 'https://www.kwestiasmaku.com/blog-kulinarny/category', include_przepisy_html=False)
stop_time_meter(start_time)
print('-----')
start_time = start_time_meter()
dinner_data = our_functions.get_recipes_data_kwestiasmaku('kolacje', 8, 'https://www.kwestiasmaku.com/przepisy', include_przepisy_html=False)
stop_time_meter(start_time)
print('-----')
# Out:
# Rozpoczęcie pomiaru czasu wykonania fragmentu kodu.
# Pobieranie URL: https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/przepisy.html
# https://www.kwestiasmaku.com/przepis/szparagi-zapiekane-z-jajkiem
# https://www.kwestiasmaku.com/przepis/croque-mademoiselle
# https://www.kwestiasmaku.com/przepis/power-bowl-z-batatami-awokado-i-jajkiem
# https://www.kwestiasmaku.com/przepis/jajka-z-rzezucha
# https://www.kwestiasmaku.com/przepis/pasta-z-fasoli
# https://www.kwestiasmaku.com/przepis/jajka-z-majonezem-truflowym
# https://www.kwestiasmaku.com/przepis/pan-bagnat
# https://www.kwestiasmaku.com/przepis/tosty-francuskie-z-solonym-karmelem
# https://www.kwestiasmaku.com/przepis/menemen
# https://www.kwestiasmaku.com/przepis/tosty-z-omletem
# https://www.kwestiasmaku.com/przepis/pieczony-nalesnik-dutch-baby-z-malinami
# https://www.kwestiasmaku.com/przepis/tosty-francuskie-z-truskawkami
# https://www.kwestiasmaku.com/przepis/szparagi-z-jajkami-i-tartym-serem-dojrzewajacym
# https://www.kwestiasmaku.com/przepis/tortilla-z-omletem-i-awokado
# https://www.kwestiasmaku.com/przepis/wrap-sniadaniowy-z-tortilli
# https://www.kwestiasmaku.com/przepis/grzanki-z-pieczonymi-pomidorkami-i-serem-kozim
# https://www.kwestiasmaku.com/przepis/komosanka
# https://www.kwestiasmaku.com/przepis/tortille-z-cukinii
# https://www.kwestiasmaku.com/przepis/hummus-z-bobu
# https://www.kwestiasmaku.com/przepis/pasztet-jajeczny
# https://www.kwestiasmaku.com/przepis/placki-czekoladowe
# https://www.kwestiasmaku.com/przepis/muffiny-jajeczne-z-marchewka-i-jarmuzem
# https://www.kwestiasmaku.com/przepis/jaglanka-z-owocami-egzotycznymi
# https://www.kwestiasmaku.com/przepis/pasta-z-makreli
# https://www.kwestiasmaku.com/przepis/pudding-z-chalki
# https://www.kwestiasmaku.com/przepis/placki
# https://www.kwestiasmaku.com/przepis/placek-owsiany-z-jablkami
# https://www.kwestiasmaku.com/przepis/pieczona-owsianka-brownie
# https://www.kwestiasmaku.com/przepis/pieczona-owsianka
# https://www.kwestiasmaku.com/przepis/pasta-z-wedzonego-lososia-i-ogorka
# https://www.kwestiasmaku.com/przepis/owsiane-muffiny-z-malinami-i-biala-czekolada
# https://www.kwestiasmaku.com/przepis/jajka-zapiekane-na-boczku
# Downloaded data from page 1
# Pobieranie URL: https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/przepisy.html?page=2
# https://www.kwestiasmaku.com/przepis/szakszuka-z-feta-i-hummusem
# https://www.kwestiasmaku.com/przepis/tosty-francuskie-z-awokado-i-jajkiem-sadzonym
# https://www.kwestiasmaku.com/przepis/pudding-ryzowy-z-karmelizowana-gruszka
# https://www.kwestiasmaku.com/przepis/jaglanka-z-sosem-tahini-i-granatem
# https://www.kwestiasmaku.com/przepis/jaglanka-z-figami-orzechami-i-miodem
# https://www.kwestiasmaku.com/przepis/paprykarz-szczecinski
# https://www.kwestiasmaku.com/przepis/racuchy-na-maslance-z-jablkami
# https://www.kwestiasmaku.com/przepis/drozdzowki-z-jablkami-i-kruszonka
# https://www.kwestiasmaku.com/przepis/dutch-baby
# https://www.kwestiasmaku.com/przepis/buleczki-cynamonowe-z-jablkami
# https://www.kwestiasmaku.com/przepis/owsianka-bounty-z-malinami
# https://www.kwestiasmaku.com/przepis/placki-twarogowe
# https://www.kwestiasmaku.com/przepis/jajka-sadzone-na-pomidorach
# https://www.kwestiasmaku.com/przepis/salaka-ze-szparagami-jajkiem-i-sosem-cezar
# https://www.kwestiasmaku.com/przepis/omlet-ze-szparagami-i-lososiem-wedzonym
# https://www.kwestiasmaku.com/przepis/puszyste-placuszki-pancakes-z-czekolada
# https://www.kwestiasmaku.com/przepis/jajka-po-ranczersku
# https://www.kwestiasmaku.com/przepis/torcik-kanapkowy-z-pasta-jajeczna
# https://www.kwestiasmaku.com/przepis/salaka-z-jajkami-kasza-jeczmienna-i-suszonymi-pomidorami
# https://www.kwestiasmaku.com/przepis/roladki-z-tortilli-z-pasta-jajeczna-suszonymi-pomidorami-i-ogorkiem
# https://www.kwestiasmaku.com/przepis/hummus-z-suszonymi-pomidorami
# https://www.kwestiasmaku.com/przepis/czekoladowy-budyn-jaglany
# https://www.kwestiasmaku.com/przepis/gofry-jaglane
# https://www.kwestiasmaku.com/przepis/szakszuka-z-jarmuzem-i-ciecierzyca
# https://www.kwestiasmaku.com/przepis/owsianka-kokosowa-z-malinami
# https://www.kwestiasmaku.com/przepis/omlet-z-pieczarkami-i-papryka
# https://www.kwestiasmaku.com/przepis/pancakes
# https://www.kwestiasmaku.com/przepis/hummus-z-dynia
# https://www.kwestiasmaku.com/przepis/smalec-z-fasoli
# https://www.kwestiasmaku.com/przepis/budyn-jaglany
# https://www.kwestiasmaku.com/przepis/pan-con-tomate
# https://www.kwestiasmaku.com/przepis/kokosowe-musli-z-truskawkami
# Downloaded data from page 2
# Pobieranie URL: https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/przepisy.html?page=3
# https://www.kwestiasmaku.com/przepis/omlet-ze-szpinakiem
# https://www.kwestiasmaku.com/przepis/jajka-faszerowane-suszonymi-pomidorami-i-feta
# https://www.kwestiasmaku.com/przepis/jajka-po-tatarsku
# https://www.kwestiasmaku.com/przepis/jajka-faszerowane-guacamole
# https://www.kwestiasmaku.com/przepis/jajka-faszerowane-szynka
# https://www.kwestiasmaku.com/przepis/omlet-z-duszonymi-porami
# https://www.kwestiasmaku.com/przepis/placki-kukurydziane
# https://www.kwestiasmaku.com/przepis/frittata-ze-szpinakiem-i-kasza-jaglana
# https://www.kwestiasmaku.com/przepis/szakszuka-z-pieczarkami-pieczona-papryka-i-feta
# https://www.kwestiasmaku.com/przepis/koktajl-z-mlodym-jeczmieniem
# https://www.kwestiasmaku.com/przepis/placuszki-z-jablkami-i-sosem-karmelowym
# https://www.kwestiasmaku.com/przepis/salatka-z-awokado-granatem-oraz-grzankami-z-kozim-serem-i-rozmarynem
# https://www.kwestiasmaku.com/przepis/budyn-jaglany-z-maslem-orzechowym-i-syropem-klonowym
# https://www.kwestiasmaku.com/przepis/crostini-z-guacamole-i-wedzonym-lososiem
# https://www.kwestiasmaku.com/przepis/jaglanka-z-bananem-i-sosem-z-masla-orzechowego
# https://www.kwestiasmaku.com/przepis/jajka-zapiekane-w-tostach-w-formie-na-muffiny
# https://www.kwestiasmaku.com/przepis/zgrzewana-kanapka-z-pomidorem-serem-kozim-i-zatarem
# https://www.kwestiasmaku.com/przepis/szakszuka-z-papryka-i-kielbasa
# https://www.kwestiasmaku.com/przepis/koktajl-brzoskwiniowy
# https://www.kwestiasmaku.com/przepis/smoothie-bowl
# https://www.kwestiasmaku.com/przepis/budyn-jaglany-z-owocami-lata-i-syropem-malinowym
# https://www.kwestiasmaku.com/przepis/owsianka-z-carpaccio-z-truskawek
# https://www.kwestiasmaku.com/przepis/jaglanka-z-jagodami
# https://www.kwestiasmaku.com/przepis/budyn-jaglano-truskawkowy
# https://www.kwestiasmaku.com/przepis/kakaowo-kawowe-bananowe-smoothie
# https://www.kwestiasmaku.com/przepis/owsianka-z-chia-i-granatem
# https://www.kwestiasmaku.com/przepis/frittata-z-szynka-szpinakiem-i-feta
# https://www.kwestiasmaku.com/przepis/puszyste-placki-z-jablkami
# https://www.kwestiasmaku.com/przepis/musli-z-jablkiem
# https://www.kwestiasmaku.com/przepis/salatka-z-jajkami-rzodkiewka-kielkami-slonecznika-i-platkami-migdalow
# https://www.kwestiasmaku.com/przepis/omlet-ze-szpinakiem-awokado-i-serem-feta
# https://www.kwestiasmaku.com/przepis/puszyste-pancakes-na-kefirze
# Downloaded data from page 3
# Pobieranie URL: https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/przepisy.html?page=4
# https://www.kwestiasmaku.com/przepis/tatar-z-suszonych-pomidorow-i-grillowanej-cukinii
# https://www.kwestiasmaku.com/przepis/bajgle
# https://www.kwestiasmaku.com/przepis/buleczki-cynamonowe-cinnamon-rolls
# https://www.kwestiasmaku.com/przepis/gofry-z-serem-i-szynka
# https://www.kwestiasmaku.com/przepis/waniliowy-budyn-jaglany
# https://www.kwestiasmaku.com/przepis/owsianka-z-mango-i-marakuja
# https://www.kwestiasmaku.com/przepis/jajka-zapiekane-w-sosie-pomidorowym
# https://www.kwestiasmaku.com/przepis/salatka-z-kasza-jaglana-awokado-papryka-i-pomidorkami
# https://www.kwestiasmaku.com/przepis/salatka-z-awokado-chrupiacym-boczkiem-i-jajkiem-w-koszulce
# https://www.kwestiasmaku.com/przepis/jajko-sadzone-z-hummusem-i-awokado
# https://www.kwestiasmaku.com/przepis/jajko-sadzone-na-soczewicy-z-awokado-i-salatka-z-pomidorow
# https://www.kwestiasmaku.com/przepis/szakszuka-z-fasolka-kukurydza-i-awokado
# https://www.kwestiasmaku.com/przepis/jajka-zapiekane-w-tostach-z-pomidorami
# https://www.kwestiasmaku.com/przepis/bruschetta-z-awokado-i-jajkiem-w-koszulce
# https://www.kwestiasmaku.com/przepis/puszyste-placki-jogurtowe-z-jagodami
# https://www.kwestiasmaku.com/przepis/owsianka-z-nasionami-chia
# https://www.kwestiasmaku.com/przepis/owoce-zapiekane-pod-kruszonka-z-platkow-owsianych
# https://www.kwestiasmaku.com/przepis/bruschetta
# https://www.kwestiasmaku.com/zielony_srodek/pomidory/jajka_w_pomidorach_z_cukinia_papryka/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/tosty_francuskie_na_slodko/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/rabarbar/jaglanka_karmelizowany_rabarbar/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/musli_power_bowl/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/wielkanoc/jajka_z_sosem_jogurtowym/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/jajka_faszerowane/jajka_faszerowane_szprotkami/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/papryka/muffiny_jajeczne_z_papryka/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/muffiny_jajeczne/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/jarmuz/jajka_zapiekane_z_jarmuzem_makrela/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/jaglanka_z_platkow_jaglanych/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/jarmuz/tosty_z_jarmuzem/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/tost_brioszka_ricotta/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/bataty/placek_z_batatow/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/ziemniaki/pieczony_placek_ziemniaczany/przepis.html
# Downloaded data from page 4
# Pobieranie URL: https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/przepisy.html?page=5
# https://www.kwestiasmaku.com/zielony_srodek/bataty/salatka_bataty_ricotta_jajko/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/szakszuka_z_chorizo_fasolka/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/budyn_jaglany/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/frittata/frittata_z_jarmuzem/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/nalesniki_jaglane/przepis.html
# https://www.kwestiasmaku.com/przepis/nalesniki-jaglane
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/jaglanka_z_jablkiem/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/placki/placki_bezglutenowe/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/brokuly/smazony_ryz_z_brokula/przepis.html
# https://www.kwestiasmaku.com/kuchnia_francuska/galettes_bretonnes/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/chia/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/jaglanka_z_mlekiem_kokosowym_zurawina/przepis.html
# https://www.kwestiasmaku.com/desery/nalesniki_bezglutenowe_na_slodko/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/owsianka/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/granola/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/jarmuz/kasza_jaglana_z_jarmuzem/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/kurki/kasza_jaglana_z_kurkami_jajkiem_sadzonym/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/awokado/jajko_zapiekane_w_awokado/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/cukinia/zapiekany_omlet_z_cukinia_i_kwiatami_cukinii/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/baklazan/szakszuka/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/jajka_w_pomidorach/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/brzoskwinie/drzem_brzoskwiniowy/przepis.html
# https://www.kwestiasmaku.com/drinki/drinki_bezalkoholowe/koktajl_truskawkowy/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/frittata/frittata_z_kurkami/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/rzodkiewka/kanapka_z_rzodkiewka_awokado_jajko/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/rzodkiewka/guacamole_z_rzodkiewka/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/frittata/frittata_ze_szpinakiem/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/pasta_jajeczna_z_feta/przepis.html
# https://www.kwestiasmaku.com/przepis/jogurt-z-owocami-miodem-i-musli
# https://www.kwestiasmaku.com/przepis/jogurt-z-syropem-klonowym
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/salatka_z_tunczykiem/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/ges/pasztet_z_gesiej_watrobki/przepis.html
# Downloaded data from page 5
# Pobieranie URL: https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/przepisy.html?page=6
# https://www.kwestiasmaku.com/kuchnia_francuska/tosty_francuskie/przepis.html
# https://www.kwestiasmaku.com/kuchnia_francuska/rillettes/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/baklazan/baba_ghanoush/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/cukinia/zapiekany_omlet_z_cukinia/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/placki/placki_jogurtowe_z_truskawkami/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/szparagi/szparagi_z_jajkiem_szynka_parmenska/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/szparagi/szparagi_z_jajkiem_w_koszulce/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/placki/placki_z_ricotty_z_bananami/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/jajka_po_florencku/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/groszek/pesto_z_zielonego_groszku/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/soczewica/jajka_z_soczewica_pomidorami/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/wielkanoc/pasta_jajeczna_z_awokado/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/wielkanoc/jajka_zapiekane/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/wielkanoc/pasta_jajeczno_lososiowa/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/tunczyk/pasta_z_tunczyka/przepis.html
# https://www.kwestiasmaku.com/domowa_piekarnia/chleb/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/pancakes_owsiane/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/wrapy_z_omletow_ziolowych/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/pancakes/pancakes.html
# https://www.kwestiasmaku.com/kuchnia_francuska/pate_z_kurzych_watrobek/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/tosty_francuskie/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/pomidory/frittata_z_pomidorami/przepis.html
# https://www.kwestiasmaku.com/desery/owoce_w_syropie/przepis.html
# https://www.kwestiasmaku.com/kuchnia_hiszpanska/tortilla_hiszpanska/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/frittata/frittata_z_porami_kozim_serem/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/frittata/frittata_z_chorizo_pomidorami_chili/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/kanapki/kanapka_pesto_z_oliwek_jajko/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/wielkanoc/jajka_z_majonezem_z_suszonymi_pomidorami/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/wielkanoc/pasta_jajeczna_z_marynowanym_ogorkiem/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/wolowina/tatar_oliwa_truflowa_suszone_pomidory/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/kanapki/kanapki_z_feta_suszonymi_pomidorami_tzatzikami/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/puszysty_omlet_na_slodko/przepis.html
# Downloaded data from page 6
# Pobieranie URL: https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/przepisy.html?page=7
# https://www.kwestiasmaku.com/dania_dla_dwojga/kanapki/kanapki_z_serem_bialym_pesto/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/jajecznica_z_tofu/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/salatki_jablka/placki_serowe_z_jablkami_rodzynkami/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/pomidory/jajka_w_kokilkach_z_pomidorami/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/tosty_z_ziolowym_omletem/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/pomidory/omlet_ze_swiezymi_pomidorami_chili/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/szparagi/szparagi_w_kokilkach/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/papryka_zapiekana_z_jajkiem/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/wielkanoc/jajka_z_majonezem_bazyliowym/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/ciecierzyca/hummus/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/wolowina/tatar/przepis.html
# https://www.kwestiasmaku.com/domowa_piekarnia/muffiny_angielskie/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/musli_dr_birchera/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/cukinia/omlet_z_cukinia/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/pasta_jajeczna_mascarpone/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/brioszka_w_szynce/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/jajka_faszerowane/z_awokado/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/drozdzowe_wypieki/brioche_blyskawiczna/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/kanapki/pesto_krewetki/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/kanapki/wyjatkowe_kanapeczki/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/ciecierzyca/pasta_z_ciecierzycy/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/fasolka/w_pomidorowym_sosie/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/awokado/pasta_z_awokado/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/gruszki/grzanki_z_gruszka/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/szparagi/jajecznica_z_pesto/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/jajka_faszerowane/z_szynka_parmenska/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/szpinak/zapiekany_z_jajkami/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/awokado/nalesniki_z_awokado/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/jajecznica_suszone_pomidory/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/jajecznica_z_lososiem/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/losos/rillettes_z_lososia/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/buraczki/pesto_z_buraczkow/przepis.html
# Downloaded data from page 7
# Pobieranie URL: https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/przepisy.html?page=8
# https://www.kwestiasmaku.com/zielony_srodek/orzechy/grzanki_z_orzechami/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/drozdzowe_wypieki/bulki_z_cynamonem/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/awokado/jajecznica_awokado/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/baklazan/pasta_z_baklazana/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/arbuz/guacamole_z_arbuzem/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/kanapki/losos_jajko_rukola/przepis.html
# https://www.kwestiasmaku.com/kuchnia_francuska/croissanty/przepis.html
# https://www.kwestiasmaku.com/kuchnia_francuska/pains_aux_raisins/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/buraczki/losos_z_buraczkami/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/jajecznica_pieczarki/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/jajka_zapiekane/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/kanapki/szynka_oliwki_brie/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/drozdzowe_wypieki/chleb_wiktorianski/przepis.html
# https://www.kwestiasmaku.com/kuchnia_francuska/brioche/brioche.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/paczuszki_z_jajkiem/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/kanapki/sardynki_maslo_szczypiorek/kanapka.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/kanapki/jajko_losos_szczypiorek/kanapka.html
# https://www.kwestiasmaku.com/kuchnia_angielska/scone/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/kanapki/jajka_suszone_pomidory/kanapka.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/losos_z_alaski/kubeczki_z_lososia/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/kukurydza/w_szynce_parmenskiej/przepis.html
# https://www.kwestiasmaku.com/przepis/jajka-po-benedyktynsku
# https://www.kwestiasmaku.com/przepis/pasta-jajeczna-z-zapiekanymi-pomidorkami
# https://www.kwestiasmaku.com/przepis/jajko-sadzone-na-szparagach
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/losos_z_alaski/kanapka_z_lososiem/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/kanapki/smalec_boczek_maslo/kanapka.html
# https://www.kwestiasmaku.com/zielony_srodek/awokado/guacamole/przepis.html
# Downloaded data from page 8
# Czas wykonania: 227.10 sekundy
# -----
# Rozpoczęcie pomiaru czasu wykonania fragmentu kodu.
# Pobieranie URL: https://www.kwestiasmaku.com/blog-kulinarny/category/dania-obiadowe
# https://www.kwestiasmaku.com/przepis/wieprzowina-stir-fry
# https://www.kwestiasmaku.com/przepis/pulpeciki-z-ryzem
# https://www.kwestiasmaku.com/przepis/kurczak-gyros-z-ziemniakami-i-papryka-zapiekany-w-papilotach
# https://www.kwestiasmaku.com/przepis/gulasz-z-cieleciny
# https://www.kwestiasmaku.com/przepis/losos-pieczony-z-batatami
# https://www.kwestiasmaku.com/przepis/kurczak-cytrynowy
# https://www.kwestiasmaku.com/przepis/dorsz-w-sosie-bazyliowym-z-pomidorkami-koktajlowymi
# https://www.kwestiasmaku.com/przepis/stifado
# https://www.kwestiasmaku.com/przepis/eskalopki-drobiowe-w-sosie-z-porem-i-pieczarkami
# https://www.kwestiasmaku.com/przepis/kurczak-w-sosie-bazyliowym-z-pomidorkami-koktajlowymi
# https://www.kwestiasmaku.com/przepis/dorsz-w-sosie-cytrynowym
# https://www.kwestiasmaku.com/przepis/kurczak-w-kremowym-sosie-cytrynowym
# https://www.kwestiasmaku.com/przepis/dorsz-po-koreansku
# https://www.kwestiasmaku.com/przepis/schab-pieczony-z-marchewka-pietruszka-i-jablkiem
# https://www.kwestiasmaku.com/przepis/filety-drobiowe-po-koreansku
# https://www.kwestiasmaku.com/przepis/losos-wellington
# https://www.kwestiasmaku.com/przepis/udka-kurczaka-po-koreansku
# https://www.kwestiasmaku.com/przepis/risotto-z-kurczakiem-po-toskansku
# https://www.kwestiasmaku.com/przepis/makaron-rigatoni-zapiekany-z-mielonym-miesem-0
# https://www.kwestiasmaku.com/przepis/indyk-w-sosie-z-dynia-i-pieczarkami
# https://www.kwestiasmaku.com/przepis/szynka-w-sosie-koperkowym
# https://www.kwestiasmaku.com/przepis/filety-drobiowe-po-grecku
# https://www.kwestiasmaku.com/przepis/schab-gotowany-w-mlodej-kapuscie
# https://www.kwestiasmaku.com/przepis/zapiekanka-z-kalafiorem-kurczakiem-ziemniakami-i-sosem-serowym
# https://www.kwestiasmaku.com/przepis/dorsz-w-slodkim-sosie-chili
# https://www.kwestiasmaku.com/przepis/steki-z-karkowki-pieczone-w-piekarniku
# https://www.kwestiasmaku.com/przepis/losos-teriyaki-pieczony-na-ryzu
# https://www.kwestiasmaku.com/przepis/rice-bowl-z-lososiem-i-salsa-mango
# https://www.kwestiasmaku.com/przepis/potrawka-z-filetow-ryb-w-sosie-z-warzywami-i-szafranem
# https://www.kwestiasmaku.com/przepis/poledwiczka-z-zurawina
# https://www.kwestiasmaku.com/przepis/kurczak-pieczony-z-ziemniakami
# https://www.kwestiasmaku.com/przepis/kurczak-z-ryzem-i-parmezanem
# Downloaded data from page 1
# Pobieranie URL: https://www.kwestiasmaku.com/blog-kulinarny/category/dania-obiadowe?page=2
# https://www.kwestiasmaku.com/przepis/kieszenie-z-kurczaka-ze-szpinakiem-i-feta
# https://www.kwestiasmaku.com/przepis/szynka-w-sosie-chrzanowym
# https://www.kwestiasmaku.com/przepis/tagine-z-kurczakiem
# https://www.kwestiasmaku.com/przepis/tortille-zapiekane-po-meksykansku
# https://www.kwestiasmaku.com/przepis/losos-w-glazurze-miso
# https://www.kwestiasmaku.com/przepis/kurczak-po-toskansku
# https://www.kwestiasmaku.com/przepis/pulpeciki-po-koreansku
# https://www.kwestiasmaku.com/przepis/losos-w-sosie-kurkowym
# https://www.kwestiasmaku.com/przepis/losos-w-sosie-curry-ze-szpinakiem-i-suszonymi-pomidorami
# https://www.kwestiasmaku.com/przepis/kurczak-z-kurkami
# https://www.kwestiasmaku.com/przepis/kurczak-w-sosie-z-cukinia-i-gorgonzola
# https://www.kwestiasmaku.com/przepis/pulpeciki-w-sosie-marinara-zapiekane-z-makaronem-i-serem
# https://www.kwestiasmaku.com/przepis/losos-w-kremowym-sosie-ze-szparagami
# https://www.kwestiasmaku.com/przepis/risotto-z-botwinka-i-kurczakiem
# https://www.kwestiasmaku.com/przepis/dorsz-ze-szpinakiem-i-chrupiaca-posypka
# https://www.kwestiasmaku.com/przepis/kurczak-gyros-w-sosie-pomidorowym-z-ciecierzyca-i-mozzarella
# https://www.kwestiasmaku.com/przepis/zeberka-po-koreansku
# https://www.kwestiasmaku.com/przepis/gulasz-wolowy
# https://www.kwestiasmaku.com/przepis/zeberka-w-piwie
# https://www.kwestiasmaku.com/przepis/kurczak-z-40-zabkami-czosnku
# https://www.kwestiasmaku.com/przepis/pieczony-halibut-z-czerwonym-ryzem-i-salsa-mango
# https://www.kwestiasmaku.com/przepis/stir-fry-z-wolowina-i-brokulami
# https://www.kwestiasmaku.com/przepis/kurczak-w-kremowym-sosie-pomidorowo-koperkowym
# https://www.kwestiasmaku.com/przepis/schab-gotowany-w-sosie-z-suszonymi-sliwkami
# https://www.kwestiasmaku.com/przepis/gulasz-wegierski-z-fileta-indyka
# https://www.kwestiasmaku.com/przepis/kurczak-po-meksykansku
# https://www.kwestiasmaku.com/przepis/cannelloni-ze-szpinakiem
# https://www.kwestiasmaku.com/przepis/gulasz-z-indyka-z-kurkami
# https://www.kwestiasmaku.com/przepis/indyk-gotowany-w-sosie
# https://www.kwestiasmaku.com/przepis/pieczone-udka-z-ziemniakami-porem-i-marchewka
# https://www.kwestiasmaku.com/przepis/makaron-z-kurczakiem-cukinia-i-sosem-alfredo
# https://www.kwestiasmaku.com/przepis/schab-w-sosie-koperkowym
# Downloaded data from page 2
# Pobieranie URL: https://www.kwestiasmaku.com/blog-kulinarny/category/dania-obiadowe?page=3
# https://www.kwestiasmaku.com/przepis/losos-z-sosem-holenderskim
# https://www.kwestiasmaku.com/przepis/tarta-z-lososiem-i-botwinka
# https://www.kwestiasmaku.com/przepis/poledwiczka-z-sosem-botwinkowym
# https://www.kwestiasmaku.com/przepis/dorsz-z-sosem-botwinkowym
# https://www.kwestiasmaku.com/przepis/poledwiczka-w-kremowym-sosie-ze-szparagami
# https://www.kwestiasmaku.com/przepis/dorsz-na-spaghetti-z-cukinii
# https://www.kwestiasmaku.com/przepis/losos-w-kremowym-sosie-z-papryka-i-szpinakiem
# https://www.kwestiasmaku.com/przepis/filety-kurczaka-zapiekane-z-serem-i-pieczarkami
# https://www.kwestiasmaku.com/przepis/filety-drobiowe-w-lekkim-sosie-koperkowym
# https://www.kwestiasmaku.com/przepis/poledwiczka-wieprzowa-w-sosie-z-whisky
# https://www.kwestiasmaku.com/przepis/pieczone-udka-kurczaka-z-tymiankiem-i-cytryna
# https://www.kwestiasmaku.com/przepis/roladki-z-kurczaka-z-pieczarkami-i-serem-pieczone-w-boczku
# https://www.kwestiasmaku.com/przepis/kurczak-z-warzywami
# https://www.kwestiasmaku.com/przepis/schab-z-suszonymi-pomidorami
# https://www.kwestiasmaku.com/przepis/schab-pieczony-z-pieczarkami
# https://www.kwestiasmaku.com/przepis/losos-pieczony-na-ryzu
# https://www.kwestiasmaku.com/przepis/parmigiana-z-kurczaka
# https://www.kwestiasmaku.com/przepis/mielone-z-indyka
# https://www.kwestiasmaku.com/przepis/filety-drobiowe-z-soczewica-i-dynia
# https://www.kwestiasmaku.com/przepis/kurczak-curry-z-dynia
# https://www.kwestiasmaku.com/przepis/filety-drobiowe-w-sosie-z-gorgonzoli
# https://www.kwestiasmaku.com/przepis/losos-miodowo-limonkowy
# https://www.kwestiasmaku.com/przepis/kurczak-w-sosie-koperkowym
# https://www.kwestiasmaku.com/przepis/udka-kurczaka-hoisin-z-ryzem
# https://www.kwestiasmaku.com/przepis/losos-caprese-z-pesto
# https://www.kwestiasmaku.com/przepis/schab-z-bobem
# https://www.kwestiasmaku.com/przepis/poledwiczki-wieprzowe-w-sosie-koperkowym
# https://www.kwestiasmaku.com/przepis/gulasz-z-indyka-z-marchewka-i-suszonymi-pomidorami
# https://www.kwestiasmaku.com/przepis/roladki-schabowe-ze-szparagami
# https://www.kwestiasmaku.com/przepis/makaron-z-kurczakiem-szparagami-i-sosem-alfredo
# https://www.kwestiasmaku.com/przepis/kurczak-ze-szparagami
# https://www.kwestiasmaku.com/przepis/losos-z-botwinka
# Downloaded data from page 3
# Pobieranie URL: https://www.kwestiasmaku.com/blog-kulinarny/category/dania-obiadowe?page=4
# https://www.kwestiasmaku.com/przepis/ryba-z-sosem-szpinakowym
# https://www.kwestiasmaku.com/przepis/golabki-bez-zawijania-w-sosie-pieczarkowym
# https://www.kwestiasmaku.com/przepis/kurczak-piccata
# https://www.kwestiasmaku.com/przepis/gulasz-z-indyka
# https://www.kwestiasmaku.com/przepis/podudzia-kurczaka-pieczone-z-pieczarkami-fasolka-i-pomidorami
# https://www.kwestiasmaku.com/przepis/nalesniki-zapiekane-z-kurczakiem-szpinakiem-i-gorgonzola
# https://www.kwestiasmaku.com/przepis/butter-chicken
# https://www.kwestiasmaku.com/przepis/nalesniki-zapiekane-po-meksykansku
# https://www.kwestiasmaku.com/przepis/pieczone-bruschetty-z-dorsza-z-pomidorami
# https://www.kwestiasmaku.com/przepis/podudzia-kurczaka-po-marokansku
# https://www.kwestiasmaku.com/przepis/pulpeciki-w-sosie-musztardowym-z-pieczarkami
# https://www.kwestiasmaku.com/przepis/placek-ziemniaczany-z-sosem-pieczarkowym-z-kurczakiem
# https://www.kwestiasmaku.com/przepis/sycylijskie-pulpeciki-drobiowe
# https://www.kwestiasmaku.com/przepis/wieprzowina-po-chinsku-z-mango
# https://www.kwestiasmaku.com/przepis/marokanskie-pulpeciki-z-kurczaka
# https://www.kwestiasmaku.com/przepis/roladki-z-kurczaka-ze-szpinakiem-i-suszonymi-pomidorami
# https://www.kwestiasmaku.com/przepis/poledwiczki-z-grzybami
# https://www.kwestiasmaku.com/przepis/poledwiczki-z-suszonymi-sliwkami
# https://www.kwestiasmaku.com/przepis/kotlet-pozarski
# https://www.kwestiasmaku.com/przepis/pieczone-udka-kaczki
# https://www.kwestiasmaku.com/przepis/placek-po-wegiersku
# https://www.kwestiasmaku.com/przepis/tagine-z-kurczaka-z-soczewica
# https://www.kwestiasmaku.com/przepis/schab-w-sosie-wegierskim
# https://www.kwestiasmaku.com/przepis/schab-w-sosie-z-dynia-i-pieczarkami
# https://www.kwestiasmaku.com/przepis/spaghetti-bolognese
# https://www.kwestiasmaku.com/przepis/schab-pieczony-w-kapuscie-kiszonej
# https://www.kwestiasmaku.com/przepis/kurczak-alla-diavola
# https://www.kwestiasmaku.com/przepis/kurczak-w-kremowym-sosie-z-dynia-i-marchewka
# https://www.kwestiasmaku.com/przepis/pieczone-udka-w-pieciu-smakach
# https://www.kwestiasmaku.com/przepis/schab-w-sosie-musztardowym
# https://www.kwestiasmaku.com/przepis/kurczak-w-kremowym-sosie-z-pesto-i-fasolka
# https://www.kwestiasmaku.com/przepis/poledwiczka-w-kremowym-sosie-z-bobem-i-koperkiem
# Downloaded data from page 4
# Pobieranie URL: https://www.kwestiasmaku.com/blog-kulinarny/category/dania-obiadowe?page=5
# https://www.kwestiasmaku.com/przepis/kluski-slaskie-z-sosem-kurkowym
# https://www.kwestiasmaku.com/przepis/udka-kurczaka-w-pomidorowym-sosie-curry
# https://www.kwestiasmaku.com/przepis/schab-gotowany-w-sosie-ze-szparagami
# https://www.kwestiasmaku.com/przepis/losos-w-sosie-harissa
# https://www.kwestiasmaku.com/przepis/pulpeciki-w-sosie-pomidorowym
# https://www.kwestiasmaku.com/przepis/pulpeciki-w-sosie-pieczarkowym
# https://www.kwestiasmaku.com/przepis/filety-z-kurczaka-zapiekane-z-ratatouille
# https://www.kwestiasmaku.com/przepis/nalesniki-zapiekane-z-mielonym-miesem
# https://www.kwestiasmaku.com/przepis/kurczak-zapiekany-z-porami
# https://www.kwestiasmaku.com/przepis/poledwiczka-w-sosie-chrzanowym
# https://www.kwestiasmaku.com/przepis/lopatka-w-sosie-z-suszonymi-pomidorami
# https://www.kwestiasmaku.com/przepis/kurczak-w-smietanie-z-marchewka-i-koperkiem
# https://www.kwestiasmaku.com/przepis/coq-au-vin-kurczak-w-winie
# https://www.kwestiasmaku.com/przepis/schab-w-sosie-borowikowym
# https://www.kwestiasmaku.com/przepis/roladki-z-kurczaka-z-pesto-szynka-i-serem
# https://www.kwestiasmaku.com/przepis/filety-z-kurczaka-w-sosie-teriyaki
# https://www.kwestiasmaku.com/przepis/chili-z-indykiem-warzywami-i-ryzem
# https://www.kwestiasmaku.com/przepis/pulpeciki-w-sosie-koperkowo-pomidorowym
# https://www.kwestiasmaku.com/przepis/dorsz-w-kremowym-sosie-z-suszonymi-pomidorami
# https://www.kwestiasmaku.com/przepis/roladki-z-kurczaka-z-pieczona-dynia-i-feta
# https://www.kwestiasmaku.com/przepis/kotlety-mielone-z-indyka
# https://www.kwestiasmaku.com/przepis/gulasz-wieprzowy-z-papryka
# https://www.kwestiasmaku.com/przepis/filety-z-kurczaka-z-marchewka-i-groszkiem
# https://www.kwestiasmaku.com/przepis/pieczone-udka-curry-z-dynia-i-ziemniakami
# https://www.kwestiasmaku.com/przepis/pulpeciki-w-sosie-dyniowo-koperkowym
# https://www.kwestiasmaku.com/przepis/schab-gotowany-w-sosie-dyniowym
# https://www.kwestiasmaku.com/przepis/filety-z-kurczaka-zapiekane-pod-kremowym-sosem-szpinakowym
# https://www.kwestiasmaku.com/przepis/poledwiczki-wieprzowe-z-mozzarella
# https://www.kwestiasmaku.com/przepis/pieczone-udka-z-kurczaka
# https://www.kwestiasmaku.com/przepis/roladki-z-indyka
# https://www.kwestiasmaku.com/przepis/kotlety-schabowe-po-meksykansku
# https://www.kwestiasmaku.com/przepis/grillowany-losos-z-sosem-kurkowym
# Downloaded data from page 5
# Pobieranie URL: https://www.kwestiasmaku.com/blog-kulinarny/category/dania-obiadowe?page=6
# https://www.kwestiasmaku.com/przepis/kotlety-mielone-w-ciescie-francuskim
# https://www.kwestiasmaku.com/przepis/schab-gotowany-w-sosie-kurkowym
# https://www.kwestiasmaku.com/przepis/roladki-z-kurczaka-z-cukinia
# https://www.kwestiasmaku.com/przepis/kotlety-mielone-prowansalskie
# https://www.kwestiasmaku.com/przepis/karkowka-pieczona-w-winie-i-czosnku-z-ziolowym-bobem
# https://www.kwestiasmaku.com/przepis/pulpeciki-z-indyka
# https://www.kwestiasmaku.com/przepis/filety-z-kurczaka-w-kremowym-sosie-z-bobem-marchewka-i-koperkiem
# https://www.kwestiasmaku.com/przepis/poledwiczki-z-kurkami
# https://www.kwestiasmaku.com/przepis/kotlety-jajeczne-z-kasza-jaglana
# https://www.kwestiasmaku.com/przepis/kotlety-schabowe
# https://www.kwestiasmaku.com/przepis/filety-z-kurczaka-w-sosie-pieczarkowym
# https://www.kwestiasmaku.com/kuchnia_polska/wieprzowina/schabowe_z_pieczarkami/przepis.html
# https://www.kwestiasmaku.com/przepis/kotlety-z-kurczaka-w-panierce-kukurydzianej
# https://www.kwestiasmaku.com/przepis/kotlety-drobiowe-z-udek-kurczaka
# https://www.kwestiasmaku.com/przepis/roladki-schabowe
# https://www.kwestiasmaku.com/przepis/schab-pieczony-z-morela
# https://www.kwestiasmaku.com/przepis/losos-z-sosem-koperkowym
# https://www.kwestiasmaku.com/przepis/pulpeciki-miesne-z-kasza-jaglana-i-suszonymi-pomidorami
# https://www.kwestiasmaku.com/przepis/losos-z-sosem-mango
# https://www.kwestiasmaku.com/przepis/kotlety-jajeczne
# https://www.kwestiasmaku.com/przepis/karkowka-pieczona-w-papilotach-z-ziemniakami-i-marchewka
# https://www.kwestiasmaku.com/przepis/kotlety-rybne-z-lososia
# https://www.kwestiasmaku.com/przepis/indyk-gotowany-w-delikatnym-sosie-z-zielonym-groszkiem
# https://www.kwestiasmaku.com/przepis/schab-gotowany-w-sosie-z-suszonymi-pomidorami
# https://www.kwestiasmaku.com/przepis/roladki-z-kurczaka-ze-szpinakiem-i-ricotta
# https://www.kwestiasmaku.com/przepis/schab-gotowany-w-sosie-z-pieczarkami
# https://www.kwestiasmaku.com/przepis/schab-w-sosie-z-porem-i-marchewka
# https://www.kwestiasmaku.com/przepis/boeuf-bourguignon-wolowina-po-burgundzku
# https://www.kwestiasmaku.com/przepis/losos-jack-daniels
# https://www.kwestiasmaku.com/przepis/poledwiczki-z-suszonymi-pomidorami
# https://www.kwestiasmaku.com/przepis/poledwiczki-w-sosie-musztardowym-z-pieczarkami
# https://www.kwestiasmaku.com/przepis/zeberka-duszone-z-warzywami-korzeniowymi
# Downloaded data from page 6
# Pobieranie URL: https://www.kwestiasmaku.com/blog-kulinarny/category/dania-obiadowe?page=7
# https://www.kwestiasmaku.com/przepis/pieczone-gesie-udka-z-rozmarynem
# https://www.kwestiasmaku.com/przepis/gesie-udka-z-dyniowym-risotto
# https://www.kwestiasmaku.com/przepis/makaron-z-pulpecikami-w-sosie-pomidorowym
# https://www.kwestiasmaku.com/przepis/gulasz-wieprzowy
# https://www.kwestiasmaku.com/przepis/filety-z-kurczaka-w-parmezanowej-panierce-pieczone-z-pomidorami-i-serem
# https://www.kwestiasmaku.com/kuchnia_polska/indyk/rolada_z_indyka/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/botwinka/kaszotto_z_kurczakiem_botwinka/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/wieprzowina/poledwiczka_cytrusowo_bakaliowa/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/ziemniaki/placek_ziemniaczany_strogonow/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/sola/sola_risotto_szafranowe/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/kurczak/kurczak_w_pomidorach_z_mozzarella/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/bataty/cottage_pie_z_batatami/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/kurczak/kurczak_zagrodowy/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/kurczak/sakiewki_z_kurczaka_z_kasza_serem_pomidorem/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/indyk/potrawka/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/indyk/makaron_zapiekany_bolognese_z_indyka/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/losos/pulpeciki_z_lososia/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/losos/losos_z_sosem_sliwkowym/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/cielecina/pulpeciki_w_sosie_pomidorowym/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/sliwki/kurczak_ze_sliwkami/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/dynia/zapiekanka_ryzowa_z_dynia/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/wieprzowina/poledwiczki_z_grzybami/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/kurczak/kurczak_w_sosie_balsamicznym/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/risotto_z_warzywami/przepis.html
# https://www.kwestiasmaku.com/pasta/makaron_muszle/muszle_faszerowane_kurczakiem_baklazanem/przepis.html
# https://www.kwestiasmaku.com/kuchnia_meksykanska/filety_z_kurczaka_po_meksykansku/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/losos/losos_chutney_mango/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/dorsz/dorsz_z_pomidorowym_pesto/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/kurczak/kurczak_szparagi_kasza_jaglana_sos_pomaranczowy/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/kurczak/grillowane_filety_z_kurczaka/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/losos/losos_chimichurri/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/kurczak/kurczak_chimichurri/przepis.html
# Downloaded data from page 7
# Pobieranie URL: https://www.kwestiasmaku.com/blog-kulinarny/category/dania-obiadowe?page=8
# https://www.kwestiasmaku.com/kuchnia_polska/wolowina/bitki_wolowe/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/dorsz/dorsz_z_kaparami/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/kurczak/filety_z_kurczaka_z_pieczarkami/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/wieprzowina/poledwiczka_w_ciescie_francuskim/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/indyk/indyk_w_sosie_pomaranczowym/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/wieprzowina/poledwiczki_wieprzowe_z_jablkami/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/wolowina/zrazy_wolowe/przepis.html
# https://www.kwestiasmaku.com/kuchnia_meksykanska/papryka_faszerowana/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/golabki/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/baklazan/golobki_z_baklazana/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/losos/losos_w_szynce_parmenskiej/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/wieprzowina/zrazy_wieprzowe/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/szparagi/poledwiczki_ze_szparagami/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/krolik/krolik_z_smietanie/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/soczewica/biryani_z_soczewica/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/kurczak/kurczak_ze_szpinakiem_gorgonzola/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/ryz/biryani_z_kalafiorem/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/groszek/kurczak_z_groszkiem/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/dorsz/dorsz_baltycki/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/wieprzowina/poledwiczki_w_szynce/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/dorada/dorada_pieczona_z_batatami/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/losos/losos_w_ciescie_francuskim/przepis.html
# https://www.kwestiasmaku.com/kuchnia_meksykanska/chili_con_carne_w_paprykach/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/kotlety_mielone/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/bitki_w_sosie_grzybowym/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/losos/losos_w_sezamie/przepis.html
# https://www.kwestiasmaku.com/kuchnia_meksykanska/mole_poblano/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/pulpeciki_w_sosie_koperkowym/przepis.html
# https://www.kwestiasmaku.com/kuchnia_hiszpanska/krolik_w_bialym_winie/przepis.html
# https://www.kwestiasmaku.com/pasta/cannelloni_z_miesem/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/kaczka/kaczka_duszona_w_soku_pomaranczowym/przepis.html
# https://www.kwestiasmaku.com/kuchnia_wloska/sos_bolonski/przepis.html
# Downloaded data from page 8
# Czas wykonania: 213.39 sekundy
# -----
# Rozpoczęcie pomiaru czasu wykonania fragmentu kodu.
# Pobieranie URL: https://www.kwestiasmaku.com/przepisy/kolacje
# https://www.kwestiasmaku.com/przepis/salatka-z-makaronem-i-paluszkami-krabowymi
# https://www.kwestiasmaku.com/przepis/tarta-ze-szparagami
# https://www.kwestiasmaku.com/przepis/szparagi-zapiekane-z-jajkiem
# https://www.kwestiasmaku.com/przepis/wiosenna-salatka-ziemniaczana-ze-szparagami-i-rzodkiewkami
# https://www.kwestiasmaku.com/przepis/ryz-smazony-z-cukinia-i-jajkiem
# https://www.kwestiasmaku.com/przepis/croque-mademoiselle
# https://www.kwestiasmaku.com/przepis/baklazan-zapiekany-po-prowansalsku
# https://www.kwestiasmaku.com/przepis/weganskie-chili-z-soczewica-i-fasola
# https://www.kwestiasmaku.com/przepis/brukselka-zapiekana-z-serem-halloumi
# https://www.kwestiasmaku.com/przepis/salatka-z-tunczykiem
# https://www.kwestiasmaku.com/przepis/salatka-z-kozim-serem-mandarynkami-i-zurawina
# https://www.kwestiasmaku.com/przepis/leczo-z-dynia
# https://www.kwestiasmaku.com/przepis/salatka-meksykanska-z-mango-i-awokado
# https://www.kwestiasmaku.com/przepis/salatka-z-burrata
# https://www.kwestiasmaku.com/przepis/pieczony-ser-halloumi-w-pomidorach-z-fasola
# https://www.kwestiasmaku.com/przepis/przystawka-z-burraty
# https://www.kwestiasmaku.com/przepis/zapiekanki-z-kurczakiem-pomidorem-i-mozzarella
# https://www.kwestiasmaku.com/przepis/ratatouille-pieczona-w-piekarniku-francuska-zapiekanka-z-warzyw
# https://www.kwestiasmaku.com/przepis/zapiekanki-z-kurczakiem-curry
# https://www.kwestiasmaku.com/przepis/roladki-z-cukinii-w-sosie-pomidorowym
# https://www.kwestiasmaku.com/przepis/salatka-z-buraczkami-i-serem-kozim
# https://www.kwestiasmaku.com/przepis/salatka-z-grillowanymi-warzywami-ciecierzyca-i-hummusem
# https://www.kwestiasmaku.com/przepis/tortilla-de-patatas-hiszpanska-tortilla-z-ziemniakami
# https://www.kwestiasmaku.com/przepis/nalesniki-z-sosem-pomaranczowym
# https://www.kwestiasmaku.com/przepis/grzanki-z-pieczonymi-pomidorkami-i-serem-kozim
# https://www.kwestiasmaku.com/przepis/salatka-z-truskawkami-feta-i-orzechami
# https://www.kwestiasmaku.com/przepis/salatka-z-botwinki-i-mango
# https://www.kwestiasmaku.com/przepis/curry-z-mlodych-ziemniakow-i-kalafiora
# https://www.kwestiasmaku.com/przepis/hiszpanski-gulasz-z-ciecierzyca-chorizo-i-szpinakiem
# https://www.kwestiasmaku.com/przepis/pisto-manchego
# https://www.kwestiasmaku.com/przepis/bataty-z-chorizo
# https://www.kwestiasmaku.com/przepis/zapiekanki-la-pizza
# Downloaded data from page 1
# Pobieranie URL: https://www.kwestiasmaku.com/przepisy/kolacje?page=2
# https://www.kwestiasmaku.com/przepis/krewetki-z-makaronem-risini-i-brokulami
# https://www.kwestiasmaku.com/przepis/kokosowy-ryz-z-mango
# https://www.kwestiasmaku.com/przepis/pieczone-bataty-z-hummusem-i-pesto-kolendrowym
# https://www.kwestiasmaku.com/przepis/pieczone-krewetki-z-maslem-i-czosnkiem
# https://www.kwestiasmaku.com/przepis/zapiekane-rozki-z-tortilli-z-mielonym-miesem-serem-i-warzywami
# https://www.kwestiasmaku.com/przepis/salatka-z-awokado-wedzona-ryba-i-oliwkami
# https://www.kwestiasmaku.com/przepis/koktajl-bananowy
# https://www.kwestiasmaku.com/przepis/medaliony-warzywne
# https://www.kwestiasmaku.com/przepis/grzanki-z-awokado-serem-salatkowym-i-granatem
# https://www.kwestiasmaku.com/przepis/gulasz-z-cukinii
# https://www.kwestiasmaku.com/przepis/makaron-zapiekany-z-cukinia-i-boczkiem
# https://www.kwestiasmaku.com/przepis/mini-pizze-z-cukinii
# https://www.kwestiasmaku.com/przepis/salatka-z-truskawkami-i-ricotta
# https://www.kwestiasmaku.com/przepis/pasta-z-wedzonej-ryby-z-jajkiem-ogorkiem-kiszonym-i-cebula
# https://www.kwestiasmaku.com/przepis/peczak-z-warzywami-po-meksykansku
# https://www.kwestiasmaku.com/przepis/tex-mex-z-kurczakiem-i-cukinia
# https://www.kwestiasmaku.com/przepis/kanapki-z-awokado-jajkiem-i-rzezucha
# https://www.kwestiasmaku.com/przepis/kasza-gryczana-smazona-z-boczkiem-i-warzywami
# https://www.kwestiasmaku.com/przepis/makaron-kokardki-z-boczkiem-i-smietanka
# https://www.kwestiasmaku.com/przepis/szaszlyki-z-kielbasy-w-ciescie-francuskim
# https://www.kwestiasmaku.com/przepis/salatka-z-kurczakiem-ananasem-i-kukurydza
# https://www.kwestiasmaku.com/przepis/chlopski-garnek
# https://www.kwestiasmaku.com/przepis/pieczone-frytki-z-warzyw
# https://www.kwestiasmaku.com/przepis/wieniec-pizzowy
# https://www.kwestiasmaku.com/przepis/makaronowa-salatka-warstwowa
# https://www.kwestiasmaku.com/przepis/babeczki-pizzowe
# https://www.kwestiasmaku.com/przepis/flaczki-z-boczniakow
# https://www.kwestiasmaku.com/przepis/zapiekanki
# https://www.kwestiasmaku.com/przepis/salatka-z-pieczonych-batatow-z-ciecierzyca
# https://www.kwestiasmaku.com/przepis/makaron-stir-fry-z-kurczakiem-brokulami-i-marchewka
# https://www.kwestiasmaku.com/przepis/ryz-smazony-z-krewetkami-na-ostro
# https://www.kwestiasmaku.com/przepis/paprykarz-szczecinski
# Downloaded data from page 2
# Pobieranie URL: https://www.kwestiasmaku.com/przepisy/kolacje?page=3
# https://www.kwestiasmaku.com/przepis/placek-z-cukinii
# https://www.kwestiasmaku.com/przepis/salatka-ryzowa-z-ananasem-i-kukurydza
# https://www.kwestiasmaku.com/przepis/marokanska-salatka-z-dorszem
# https://www.kwestiasmaku.com/przepis/strogonow-drobiowy
# https://www.kwestiasmaku.com/przepis/salatka-z-truskawkami-i-mango
# https://www.kwestiasmaku.com/przepis/szparagi-zapiekane-z-szynka-parmenska-i-serem
# https://www.kwestiasmaku.com/przepis/salatka-z-buraka-i-mango
# https://www.kwestiasmaku.com/przepis/ryz-smazony-z-kurczakiem-po-meksykansku
# https://www.kwestiasmaku.com/przepis/pizzadilla-z-salami-i-papryka
# https://www.kwestiasmaku.com/przepis/torcik-kanapkowy-z-pasta-jajeczna
# https://www.kwestiasmaku.com/przepis/hummus-z-suszonymi-pomidorami
# https://www.kwestiasmaku.com/przepis/zestaw-lunchowy-z-kasza-gryczana-i-warzywami
# https://www.kwestiasmaku.com/przepis/ryz-smazony-po-tajsku-z-krewetkami-i-mango
# https://www.kwestiasmaku.com/przepis/burgery-z-batatow-fasoli-i-quinoa
# https://www.kwestiasmaku.com/przepis/zestaw-lunchowy-z-pieczonym-batatem
# https://www.kwestiasmaku.com/przepis/roladki-z-tortilli-z-szynka-parmenska-pomidorem-i-parmezanem
# https://www.kwestiasmaku.com/przepis/pieczone-bataty-z-feta-pesto-i-granatem
# https://www.kwestiasmaku.com/przepis/nasi-goreng
# https://www.kwestiasmaku.com/przepis/forszmak
# https://www.kwestiasmaku.com/przepis/curry-warzywne-z-ziemniakami-kalafiorem-i-szpinakiem
# https://www.kwestiasmaku.com/przepis/nalesniki-ze-szpinakiem-feta-i-suszonymi-pomidorami
# https://www.kwestiasmaku.com/przepis/quesadilla-z-kurczakiem-i-warzywami
# https://www.kwestiasmaku.com/przepis/hummus-z-dynia
# https://www.kwestiasmaku.com/przepis/budyn-jaglany
# https://www.kwestiasmaku.com/przepis/gulasz-z-baklazana-z-wedzona-papryka
# https://www.kwestiasmaku.com/przepis/salatka-makaronowa-z-chorizo-pomidorkami-i-oliwkami
# https://www.kwestiasmaku.com/przepis/salatka-makaronowa-z-pomidorami-oliwkami-i-feta
# https://www.kwestiasmaku.com/przepis/cukinia-smazona-w-ciescie-nalesnikowym
# https://www.kwestiasmaku.com/przepis/fasolka-szparagowa-z-pomidorkami-i-feta
# https://www.kwestiasmaku.com/przepis/leczo-z-cukinia
# https://www.kwestiasmaku.com/przepis/frytki-z-cukinii
# https://www.kwestiasmaku.com/przepis/krewetki-z-patelni-z-kurkami-i-czosnkiem
# Downloaded data from page 3
# Pobieranie URL: https://www.kwestiasmaku.com/przepisy/kolacje?page=4
# https://www.kwestiasmaku.com/przepis/salatka-z-kaszy-bulgur-z-feta-ogorkiem-i-granatem
# https://www.kwestiasmaku.com/przepis/pieczone-bataty-z-ciecierzyca-szpinakiem-i-feta
# https://www.kwestiasmaku.com/przepis/pizzowy-warkocz-z-salami-i-serem
# https://www.kwestiasmaku.com/przepis/cukinia-faszerowana-kasza-jaglana-i-krewetkami
# https://www.kwestiasmaku.com/przepis/placki-kukurydziane
# https://www.kwestiasmaku.com/przepis/pieczone-nuggetsy-z-kurczaka-z-sosem-arrabiatta
# https://www.kwestiasmaku.com/przepis/curry-pomidorowe-z-dorszem-i-ciecierzyca
# https://www.kwestiasmaku.com/przepis/salatka-z-awokado-granatem-oraz-grzankami-z-kozim-serem-i-rozmarynem
# https://www.kwestiasmaku.com/przepis/crostini-z-guacamole-i-wedzonym-lososiem
# https://www.kwestiasmaku.com/przepis/roladki-z-tortilli-z-tunczykiem-i-kukurydza
# https://www.kwestiasmaku.com/przepis/enchilada-z-kurczakiem
# https://www.kwestiasmaku.com/przepis/ryz-smazony-z-kurczakiem-brokulami-i-marchewka
# https://www.kwestiasmaku.com/przepis/salatka-z-grillowanym-kurczakiem-pomarancza-i-orzechami
# https://www.kwestiasmaku.com/przepis/szakszuka-z-papryka-i-kielbasa
# https://www.kwestiasmaku.com/przepis/placek-leczo
# https://www.kwestiasmaku.com/przepis/tajskie-burgery-drobiowe
# https://www.kwestiasmaku.com/przepis/leczo
# https://www.kwestiasmaku.com/przepis/zapiekanka-makaronowa-z-lososiem-wedzonym-i-szpinakiem
# https://www.kwestiasmaku.com/przepis/ciecierzyca-po-bretonsku
# https://www.kwestiasmaku.com/przepis/salatka-z-feta-pomidorkami-i-kukurydza
# https://www.kwestiasmaku.com/przepis/burgery-z-kurczakiem
# https://www.kwestiasmaku.com/przepis/nalesniki-zapiekane-ze-szpinakiem-w-sosie-pomidorowym
# https://www.kwestiasmaku.com/przepis/zeberka-w-kapuscie
# https://www.kwestiasmaku.com/przepis/tatar-z-suszonych-pomidorow-i-grillowanej-cukinii
# https://www.kwestiasmaku.com/przepis/bajgle
# https://www.kwestiasmaku.com/przepis/nalesniki-z-pasztetem-roslinnym-i-warzywami
# https://www.kwestiasmaku.com/przepis/pasztet-gryczany-z-pieczonych-warzyw
# https://www.kwestiasmaku.com/przepis/gofry-z-serem-i-szynka
# https://www.kwestiasmaku.com/przepis/kasza-gryczana-smazona-z-marchewka-kalafiorem-i-jarmuzem
# https://www.kwestiasmaku.com/przepis/waniliowy-budyn-jaglany
# https://www.kwestiasmaku.com/przepis/kasza-gryczana-smazona-z-kurczakiem-i-warzywami
# https://www.kwestiasmaku.com/przepis/papryki-faszerowane
# Downloaded data from page 4
# Pobieranie URL: https://www.kwestiasmaku.com/przepisy/kolacje?page=5
# https://www.kwestiasmaku.com/przepis/bigos-z-kiszonej-kapusty-z-soczewica-i-dynia
# https://www.kwestiasmaku.com/przepis/zapiekana-dynia-w-chrupiacej-panierce
# https://www.kwestiasmaku.com/przepis/curry-z-ciecierzycy
# https://www.kwestiasmaku.com/przepis/focaccia-z-pomidorkami-koktajlowymi
# https://www.kwestiasmaku.com/przepis/pierogi-ze-szpinakiem-zapiekane-w-sosie-pomidorowym
# https://www.kwestiasmaku.com/przepis/leczo-z-soczewica-i-dynia
# https://www.kwestiasmaku.com/przepis/bruschetta
# https://www.kwestiasmaku.com/przepis/baklazan-zapiekany-z-caprese
# https://www.kwestiasmaku.com/zielony_srodek/botwinka/tarta_z_botwinka_kozim_serem/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/cukinia/cukinia_nadziewana_kasza_jaglana/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/papryka/muffiny_jajeczne_z_papryka/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/cukinia/kasza_jaglana_cukinia_jarmuz/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/jarmuz/jajka_zapiekane_z_jarmuzem_makrela/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/indyk/makaron_ryzowy_z_indykiem/przepis.html
# https://www.kwestiasmaku.com/drinki/drinki_bezalkoholowe/smoothie_z_jarmuzu/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/losos/salatka_z_lososiem_awokado/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/salatka_z_komosy_ryzowej/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/marchewka/pieczona_marchewka_z_imbirem/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/budyn_jaglany/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/marchewka/pieczona_marchew/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/jarmuz/bigos_z_jarmuzu/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/jaglanka_z_jablkiem/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/brokuly/smazony_ryz_z_brokula/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/szpinak/stir_fry_kasza_gryczana/przepis.html
# https://www.kwestiasmaku.com/kuchnia_francuska/galettes_bretonnes/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/kaczka/rillettes_z_kaczki/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/nalesniki_bezglutenowe/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/losos/burgery_z_lososia_z_kasza_jaglana/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/cukinia/cukinia_faszerowana/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/cukinia/cukinia_zapiekana_caprese/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/salatki_jablka/jablka_pieczone/jablka_pieczone_z_platkami_owsianymi/przepis.html
# https://www.kwestiasmaku.com/kuchnia_orientu/curry/curry_kurczak_fasolka/przepis.html
# Downloaded data from page 5
# Pobieranie URL: https://www.kwestiasmaku.com/przepisy/kolacje?page=6
# https://www.kwestiasmaku.com/przepis/salatka-z-awokado-pomidorami-i-mozzarella
# https://www.kwestiasmaku.com/zielony_srodek/pomidory/salatka_pomidor_awokado/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/fasolka/fasolka_po_bretonsku/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/pomidory/fasolka_w_sosie_pomidorowym/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/baklazan/panino_z_baklazanem/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/baklazan/baklazan_zapiekany_z_serem_kozim_i_pomidorami/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/baklazan/baklazan_z_mozzarella/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/fasolka/fasolka_szparagowa_z_porami/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/losos/tatar_z_lososia/przepis.html
# https://www.kwestiasmaku.com/kuchnia_orientu/chow_mein/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/mango/makaron_sojowy_z_mango/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/nalesniki_bazyliowe/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/krewetki/placuszki_krewetkowe/przepis.html
# https://www.kwestiasmaku.com/pasta/makaron_muszle/muszle_makaronowe_tunczyk_mozzarella/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/tarty_tartaletki_quiche/pizza_na_ciescie_francuskim/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/melon/salatka_z_kurczakiem_melonem/przepis.html
# https://www.kwestiasmaku.com/pasta/z_szynka_parmenska/makaron_z_karczochami_szynka_parmenska/przepis.html
# https://www.kwestiasmaku.com/drinki/drinki_bezalkoholowe/zielone_smoothie/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/pieczone_warzywa/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/tarty_tartaletki_quiche/tarta_pizza/przepis.html
# https://www.kwestiasmaku.com/przepis/jogurt-z-syropem-klonowym
# https://www.kwestiasmaku.com/zielony_srodek/bataty/pieczone_bataty_salatka/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/gruszki/salatka_z_roszponki_z_kozim_serem_gruszka/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/salatka_z_tunczykiem/przepis.html
# https://www.kwestiasmaku.com/kuchnia_wloska/pizza/pizza_domowa/przepis.html
# https://www.kwestiasmaku.com/kuchnia_meksykanska/papryka_faszerowana/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/cukinia/pieczone_talarki_cukinii/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/baklazan/curry_z_baklazanem_pomidorami/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/pomidory/pomidory_faszerowane_kurkami/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/truskawki/salatka_z_truskawkami_awokado/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/awokado/salatka_z_awokado_szpinakiem_serem_kozim/przepis.html
# https://www.kwestiasmaku.com/kuchnia_orientu/tajska_salatka_z_krewetkami/przepis.html
# Downloaded data from page 6
# Pobieranie URL: https://www.kwestiasmaku.com/przepisy/kolacje?page=7
# https://www.kwestiasmaku.com/domowa_piekarnia/chleb_na_kanapki/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/krewetki/krewetki_z_patelni/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/salatka_z_serem_kozim_musztarda_francuska/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/granat/salatka_z_kozim_serem_granatem/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/losos/sushi_z_lososiem_teriyaki/przepis.html
# https://www.kwestiasmaku.com/domowa_piekarnia/chleb/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/party/salatka_z_winogronami/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/kurczak/kurczak_slodko_kwasny/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/soczewica/dal_z_soczewicy/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/losos/losos_w_sezamie/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/krewetki/salatka_z_pomelo_krewetek/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/party/empanadas/przepis.html
# https://www.kwestiasmaku.com/domowa_piekarnia/bagietka/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/ziemniaki/ziemniaki_pieczone_z_szalwia/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/kuskus/kuskus_z_cukinia_mieta_feta/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/mango/salatka_z_mango_imbirem_limonka/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/losos/makaron_ryzowy_z_pieczonym_lososiem/przepis.html
# https://www.kwestiasmaku.com/pasta/z_pomidorami/szybkie_spaghetti_bolognese/przepis.html
# https://www.kwestiasmaku.com/pasta/z_pomidorami/makaron_z_pomidorami_mozzarella_bazylia/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/papryka/leczo/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/baklazan/stir_fry_z_baklazanem/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/kurczak/kurczak_w_jogurcie/przepis.html
# https://www.kwestiasmaku.com/przepis/salatka-grecka-z-grzankami-i-salata-lodowa
# https://www.kwestiasmaku.com/dania_dla_dwojga/salatka_grecka/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/frittata/frittata_z_porami_kozim_serem/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/frittata/frittata_z_chorizo_pomidorami_chili/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/kanapki/kanapka_pesto_z_oliwek_jajko/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/cukinia/salatka_z_makaronem_ryzowym_grillowana_cukinia/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/wolowina/tatar_oliwa_truflowa_suszone_pomidory/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/kanapki/kanapka_ze_stekiem_i_majonezem_truflowym/przepis.html
# https://www.kwestiasmaku.com/kuchnia_orientu/makaron_ryzowy_z_miso/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/kanapki/kanapki_z_feta_suszonymi_pomidorami_tzatzikami/przepis.html
# Downloaded data from page 7
# Pobieranie URL: https://www.kwestiasmaku.com/przepisy/kolacje?page=8
# https://www.kwestiasmaku.com/dania_dla_dwojga/kanapki/kanapki_z_serem_bialym_pesto/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/kanapki/kanapka_z_lososiem_wedzonym_serkiem_koperkiem/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/walentynki/tarta_z_ciasta_francuskiego/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/stir_fry_z_kasza_jeczmienna/przepis.html
# https://www.kwestiasmaku.com/kuchnia_orientu/ryz_po_tajsku/przepis.html
# https://www.kwestiasmaku.com/kuchnia_angielska/kurczak_tikka_masala/przepis.html
# https://www.kwestiasmaku.com/kuchnia_orientu/makaron_ryzowy_z_krewetkami_warzywami/przepis.html
# https://www.kwestiasmaku.com/kuchnia_wloska/focaccia_z_oliwkami_serem/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/szpinak/rozki_ze_szpinakiem/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/papryka/papryki_zapiekane_z_ryzem_miesem/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/kalafior/kalafior_z_granatem_pomarancza/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/krewetki/krewetki_slodko_kwasne/przepis.html
# https://www.kwestiasmaku.com/domowa_piekarnia/ciabatta_przepis_bez_wyrabiania/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/sniadania/tosty_z_ziolowym_omletem/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/ciecierzyca/hummus/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/awokado/salatka_z_awokado_mozzarelli/przepis.html
# https://www.kwestiasmaku.com/kuchnia_wloska/ryba_z_borowikami_krewetkami/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/ziemniaki/frytki_pieczone/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/focaccia_z_mozzarella_zielonym_pesto/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/grzyby/tosty_z_grzybami_mozzarella_szpinak/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/walentynki/quiche_fillo/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/ziemniaki/placki_ziemniaczane/przepis.html
# https://www.kwestiasmaku.com/kuchnia_orientu/bulion_chinski/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/fasolka/w_pomidorowym_sosie/przepis.html
# https://www.kwestiasmaku.com/desery/ryz_zapiekany/przepis.html
# https://www.kwestiasmaku.com/dania_dla_dwojga/frittata/tortilla_hiszpanska/przepis.html
# https://www.kwestiasmaku.com/zielony_srodek/salatki_jablka/jablka_pieczone/z_rodzynkami/przepis.html
# https://www.kwestiasmaku.com/ryby_i_owoce_morza/losos/rillettes_z_lososia/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/pasztet_drobiowy/przepis.html
# https://www.kwestiasmaku.com/kuchnia_polska/placki/bliny_gryczane/przepis.html
# https://www.kwestiasmaku.com/kuchnia_wloska/krewetki_z_fasolka/przepis.html
# https://www.kwestiasmaku.com/kuchnia_wloska/placek_z_ligurii/przepis.html
# Downloaded data from page 8
# Czas wykonania: 221.96 sekundy
# -----

# %%
df = pd.DataFrame(breakfast_data + main_dish_data + dinner_data)

# %%
df.head()
# Out:
#     category                              recipe_title  \
# 0  sniadania              Szparagi zapiekane z jajkiem
# 1  sniadania                       Croque Mademoiselle
# 2  sniadania  Power bowl z batatami, awokado i jajkiem
# 3  sniadania                          Jajka z rzeżuchą
# 4  sniadania                            Pasta z fasoli
#
#                                          ingredients  \
# 0  1/2 pęczka szparagów;1 łyżeczka masła;100 g po...
# 1  4 duże kromki chleba np. na zakwasie;1 cukinia...
# 2  1 batat;1/2 ząbka czosnku;sól, pieprz, 1/2 łyż...
# 3  10 jajek;4 łyżki majonezu;2 łyżeczki musztardy...
# 4  1 puszka białej fasolki (400 g);150 g korzenia...
#
#                                   preparation_method rating opinions_count
# 0  Piekarnik nagrzać do180 stopni C. Dno naczynia...   4.79             14
# 1  Cukinię umyć, odciąć końce, pokroić na ok. 0,5...   4.75              4
# 2  Piekarnik nagrzać do 210 stopni C. Batata obra...   4.71              7
# 3  Jajka ugotować na twardo (6 minut od zagotowan...    4.5              4
# 4  Fasolkę odcedzić na sitku. Selera obrać i pokr...      5              3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 763 entries, 0 to 762
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   category            763 non-null    object
#  1   recipe_title        763 non-null    object
#  2   ingredients         763 non-null    object
#  3   preparation_method  763 non-null    object
#  4   rating              763 non-null    object
#  5   opinions_count      763 non-null    object
# dtypes: object(6)
# memory usage: 35.9+ KB

# %% [markdown]
# Dzięki funkcji df.info() dowiadujemy się o jego strukturze, wiemy że jest to DataFrame, że zawiera 763 wiersze z indeksami o 0 do 762, że zawiera 6 kolumn, że nie ma brakujących danch (non-null), ze typy danych dla wszytskich kolumn to object czyli stringi.

# %%
df.to_csv('recipes_kwestiasmaku.csv', index=False)
df.to_parquet('recipes_kwestiasmaku.parquet', index=False)

# %%
df = pd.read_csv('recipes_kwestiasmaku.csv')
df.head()

# %% [markdown]
# ## Scrapowanie drugiej strony z przepisami (przepisy.pl)

# %%
# Pobieramy url na podstawie kategorii i numeru strony
def get_recipe_page_przepisy(category, page_number):
    url = f'https://www.przepisy.pl/przepisy/posilek/{category}?page={page_number}'
    response = requests.get(url, headers=headers)
    # sleep(2)  # Dodanie opóźnienia, aby nie obciążać serwera
    return BeautifulSoup(response.content, 'html.parser')

# Pobieramy szczegółowe informacje o przepisie
def get_recipe_details_przepisy(recipe_url, category):
    response = requests.get(recipe_url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    # znajdowanie tytułu
    title_element = soup.find('h1', {'class': 'title'})
    recipe_title = title_element.get_text(strip=True) if title_element else 'Brak tytułu'
    # znajdowanie składników
    ingredients_list = soup.find_all('span', {'class': 'text-bg-white'})
    ingredients = '; '.join([ingredient.get_text(strip=True) for ingredient in ingredients_list])
    # znajdowanie sposobu przygotowania
    preparation_method_element = soup.find('div', {'class': 'steps-list-wrapper ng-star-inserted'})
    preparation_method = preparation_method_element.get_text(strip=True) if preparation_method_element else 'Brak sposobu przygotowania'
    # znajdowanie oceny
    rating_elements_full = soup.find_all('app-asset-ico-rating', class_='ico-rating ng-star-inserted')
    rating_elements_half = soup.find_all('app-asset-ico-rating', class_='ico-rating last ng-star-inserted')
    rating = len(rating_elements_full) + len(rating_elements_half) * 0.5
    # znajdowanie liczby opinii
    opinions_count_element = soup.find('div', {'class': 'comments-list-container ng-star-inserted'})
    opinions_count_p = opinions_count_element.find('p', class_='average-count rating-total') if opinions_count_element else None
    opinions_count = opinions_count_p.get_text(strip=True) if opinions_count_p else 'Brak opinii'
    # znajdowanie czasu przygotowania
    preparation_time_element = soup.find('div', {'class': 'time-count'})
    preparation_time = preparation_time_element.get_text(strip=True) if preparation_time_element else 'Brak informacji'
    # sprawdzanie czy danie jest wegetariańskie
    vegetarian_element = soup.find('a', href="/przepisy/wege")
    vegetarian = bool(vegetarian_element and 'Wege' in vegetarian_element.text)

    return {'category': category, 'recipe_title': recipe_title, 'ingredients': ingredients, 'preparation_method': preparation_method, 'rating': rating, 'opinions_count': opinions_count, 'preparation_time': preparation_time, 'vegetarian': vegetarian, }

# Iterujemy przez określoną liczę stron w danej kategorii, pobierając i zbierając szcegóły przepisów
def get_recipes_data_przepisy(categories, number_of_pages):
    all_recipes = []
    for category in categories:
        for page_number in range(1, number_of_pages + 1):
            soup = get_recipe_page_przepisy(category, page_number)
            if not soup:
              continue
            links = soup.find_all('a', class_='recipe-box__title')
            for link in links:
                recipe_url = 'https://www.przepisy.pl' + link['href']
                recipe_data = get_recipe_details_przepisy(recipe_url, category)
                if recipe_data:
                  all_recipes.append(recipe_data)
    return all_recipes

# %%
start_time = start_time_meter()
breakfast_data_1 = get_recipes_data_przepisy(['sniadanie'], 9)
print(f'Liczba przepisów: {len(breakfast_data_1)}')
print('-----')
stop_time_meter(start_time)
# Out:
# Rozpoczęcie pomiaru czasu wykonania fragmentu kodu.
# Liczba przepisów: 272
# -----
# Czas wykonania: 243.80 sekundy

# %%
start_time = our_functions.start_time_meter()
main_dish_data_1 = get_recipes_data_przepisy(['obiad'], 20)
print(f'Liczba przepisów: {len(main_dish_data_1)}')
print('-----')
our_functions.stop_time_meter(start_time)
# Out:
# Rozpoczęcie pomiaru czasu wykonania fragmentu kodu.
# Liczba przepisów: 620
# -----
# Czas wykonania: 715.23 sekundy

# %%
start_time = our_functions.start_time_meter()
dinner_data_1 = get_recipes_data_przepisy(['kolacja'], 20)
print(f'Liczba przepisów: {len(dinner_data_1)}')
print('-----')
our_functions.stop_time_meter(start_time)
# Out:
# Rozpoczęcie pomiaru czasu wykonania fragmentu kodu.
# Liczba przepisów: 620
# -----
# Czas wykonania: 618.72 sekundy

# %%
df_1 = pd.DataFrame(breakfast_data_1 + main_dish_data_1 + dinner_data_1)

# %%
df_1.head()
# Out:
#     category                                       recipe_title  \
# 0  sniadanie                                          Szakszuka
# 1  sniadanie                                   Hiszpański omlet
# 2  sniadanie                         Kremowa kanapka z indykiem
# 3  sniadanie  Kanapki z pastą rybną z jajkiem i ogórkiem kon...
# 4  sniadanie               Kanapka BLT (bekon, pomidor, sałata)
#
#                                          ingredients  \
# 0  jajka; 4 sztuki; Przyprawa do warzyw z grilla ...
# 1  jajko; 5 sztuk; Majonez Hellmann's Oryginalny;...
# 2  chleb żytni na zakwasie, kromki; 4 sztuki; pie...
# 3  Majonez Hellmann's Oryginalny; 3 łyżki; makrel...
# 4  kromki chleba tostowego; 8 sztuk; Majonez Hell...
#
#                                   preparation_method  rating opinions_count  \
# 0  Krok 1Sparz pomidory do szakszuki z piekarnika...     4.5    Brak opinii
# 1  Krok 1Przygotuj wszystkie składniki: cebulę i ...     4.5    Brak opinii
# 2  Krok 1Rozgrzej patelnię grillową lub opiekacz,...     4.5    Brak opinii
# 3  Krok 1Jaja ugotuj na twardo obierz zetrzyj na ...     4.5    Brak opinii
# 4  Krok 1Na patelni na średnim ogniu usmażyć bocz...     4.5    Brak opinii
#
#   preparation_time  vegetarian
# 0          25 min.        True
# 1          30 min.        True
# 2          15 min.        True
# 3          15 min.        True
# 4          10 min.        True

# %%
df_1.to_csv('recipes_przepisy.csv', index=False)
df_1.to_parquet('recipes_przepisy.parquet', index=False)

# %%
df_1 = pd.read_csv('recipes_przepisy.csv')

# %%
df_1.head()

# %% [markdown]
# ## Scrapowanie trzeciej strony z przepisami (aniastarmach.pl) TW

# %%
# Pobieramy strony z HTML z danego URL i zwracanie jej zawartości jako obiektu BeautifulSoup
def get_page(url):
    response = requests.get(url, headers=headers)
    if response.status_code == 404:  # Sprawdzenie, czy strona nie istnieje
        return None
    return BeautifulSoup(response.text, 'html.parser')

# Pobieramy nazw i URL-ów przepisów z danej strony kategorii
def get_recipes_names_urls_for_page(page_url):
    soup = get_page(page_url)
    if soup is None:  # Jeśli strona nie istnieje, zwróć puste listy
        return [], [], True
    recipes_names, recipes_urls = [], []
    recipes = soup.find_all('div', class_='recipe')
    for recipe in recipes:
        title = recipe.get('data-title')
        recipe_url = recipe.find('a', class_='overlay')['href']
        recipes_names.append(title)
        recipes_urls.append(recipe_url)
    return recipes_names, recipes_urls, False

# Pobieranie szczegółowych informacji o przepisach
def get_receipes_details(recipes_urls, category):
    recipes_data = []
    for url in recipes_urls:
        soup = get_page(url)
        if soup is None:
            continue

        # Pobieranie i czyszczenie nazwy potrawy
        recipe_title = soup.find('div', class_='recipe').get('data-title', 'Brak tytułu')
        recipe_title = recipe_title.replace('\n', '').replace(';', '=')

        # Pobieranie i czyszczenie składników
        items = soup.find('div', class_='recipe-what-to-buy')
        ingredients_descriptions = []
        if items:
            items = items.find_all('li')
        for item in items:
            quantity = item.find('span', class_='quantity')
            quantity = quantity.text.strip() if quantity else 'do smaku'
            ingredient_name = item.text.strip().replace(quantity, '', 1).strip()
            description = f"{quantity} {ingredient_name}" if quantity != 'do smaku' else ingredient_name
            ingredients_descriptions.append(description)
        ingredients = '; '.join(ingredients_descriptions)
        ingredients = ingredients.replace('\n', '').replace(';', '=')

        # Pobieranie i czyszczenie sposobu przygotowania
        steps_section = soup.find('div', class_='recipe-steps')
        preparation = "Brak informacji"
        if steps_section:
            steps = steps_section.find_all('li')
            preparation_steps = []
            for step in steps:
                p = step.find('p')
                step_text = p.text.strip() if p else step.text.strip()
                preparation_steps.append(step_text)
            preparation = "\n\n".join(preparation_steps)
        preparation = preparation.replace('\n', '').replace(';', '=')

        # Pozostałe elementy
        time_section = soup.find('div', class_='recipe-icon icon-timer')
        preparation_time = time_section.span.text.strip() + " min" if time_section and time_section.span else "Brak informacji"

        vegetarian_icon = soup.find('div', class_='recipe-icon icon-vegetarian')
        is_vegetarian = bool(vegetarian_icon)

        recipes_data.append({
            'category': category,
            'recipe_title': recipe_title,
            'ingredients': ingredients,
            'preparation_method': preparation,
            'preparation_time': preparation_time,
            'vegetarian': is_vegetarian,
        })

    return recipes_data

# %%
start_time = start_time_meter()

categories = ['sniadanie', 'obiad', 'kolacja']

all_recipes_details = []

for category in categories:
    recipes_names, recipes_urls = [], []
    base_url = f"https://aniastarmach.pl/przepisy/pora-dnia/{category}/strona/"
    page_number = 1
    while (page_number < 10):
        names, urls, not_found = get_recipes_names_urls_for_page(base_url + str(page_number) + "/")
        if not_found:
            break
        recipes_names.extend(names)
        recipes_urls.extend(urls)
        page_number += 1

    category_recipes_details = get_receipes_details(recipes_urls, category)
    all_recipes_details.extend(category_recipes_details)

print('-----')
stop_time_meter(start_time)
# Out:
# Rozpoczęcie pomiaru czasu wykonania fragmentu kodu.
# -----
# Czas wykonania: 580.53 sekundy

# %%
df_2 = pd.DataFrame(all_recipes_details)

# %%
df_2.head()
# Out:
#     category                        recipe_title  \
# 0  sniadanie                        Minifrittaty
# 1  sniadanie  Placuszki z kuskusu i białego sera
# 2  sniadanie                        Minifrittaty
# 3  sniadanie                    Tosty trójkąciki
# 4  sniadanie                  Naleśniki „ruskie”
#
#                                          ingredients  \
# 0  4 jajka= 1 awokado= 1 łyżeczka soku z cytryny=...
# 1  4 łyżki kaszy jaglanej= 1 szklanka mleka kokos...
# 2  4 duże kromki chleba= 100 g sera ricotta= 1 ły...
# 3  5 łyżek płatków owsianych górskich= 200 ml mle...
# 4  4 jajka= 50 ml mleka= 0.5 łyżki masła= 8 pomid...
#
#                                   preparation_method preparation_time  \
# 0  Jajka ugotuj na twardo, obierz ze skorupek, pr...           15 min
# 1  Kaszę przelej zimną, potem ciepłą wodą. Przełó...           20 min
# 2  Szynkę pokrój w kostkę, wrzuć na rozgrzaną pat...           10 min
# 3  Płatki owsiane przełóż do niewielkiego rondelk...           20 min
# 4  Szynkę pokrój w cienkie paseczki, mozzarellę –...           15 min
#
#    vegetarian
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False

# %%
# Dodajemy dwie nowe kolumny do naszego df ponieważ w innych stronach te kolumny występowały
prep_method_idx = df_2.columns.get_loc('preparation_method') + 1
df_2.insert(prep_method_idx, 'rating', np.nan)
df_2.insert(prep_method_idx + 1, 'opinions_count', np.nan)

# %%
df_2.head()
# Out:
#     category                        recipe_title  \
# 0  sniadanie                        Minifrittaty
# 1  sniadanie  Placuszki z kuskusu i białego sera
# 2  sniadanie                        Minifrittaty
# 3  sniadanie                    Tosty trójkąciki
# 4  sniadanie                  Naleśniki „ruskie”
#
#                                          ingredients  \
# 0  4 jajka= 1 awokado= 1 łyżeczka soku z cytryny=...
# 1  4 łyżki kaszy jaglanej= 1 szklanka mleka kokos...
# 2  4 duże kromki chleba= 100 g sera ricotta= 1 ły...
# 3  5 łyżek płatków owsianych górskich= 200 ml mle...
# 4  4 jajka= 50 ml mleka= 0.5 łyżki masła= 8 pomid...
#
#                                   preparation_method  rating  opinions_count  \
# 0  Jajka ugotuj na twardo, obierz ze skorupek, pr...     NaN             NaN
# 1  Kaszę przelej zimną, potem ciepłą wodą. Przełó...     NaN             NaN
# 2  Szynkę pokrój w kostkę, wrzuć na rozgrzaną pat...     NaN             NaN
# 3  Płatki owsiane przełóż do niewielkiego rondelk...     NaN             NaN
# 4  Szynkę pokrój w cienkie paseczki, mozzarellę –...     NaN             NaN
#
#   preparation_time  vegetarian
# 0           15 min        True
# 1           20 min        True
# 2           10 min        True
# 3           20 min        True
# 4           15 min       False

# %%
df_2.to_csv('recipes_aniastarmach.csv',index=False)
df_2.to_parquet('recipes_aniastarmach.parquet',index=False)

# %%
df_2 = pd.read_csv('recipes_aniastarmach.csv')

# %%
df_2.head()

# %% [markdown]
# ## Składanie w jednego df_recipes

# %%
# Łączymy 3 obiekty DataFrame, argument ignore_index ignoruje indexy i ponownie zaindeksuje od 0
df_recipes = pd.concat([df, df_1, df_2], ignore_index=True)

# %%
df_recipes.head()
# Out:
#     category                              recipe_title  \
# 0  sniadania              Szparagi zapiekane z jajkiem
# 1  sniadania                       Croque Mademoiselle
# 2  sniadania  Power bowl z batatami, awokado i jajkiem
# 3  sniadania                          Jajka z rzeżuchą
# 4  sniadania                            Pasta z fasoli
#
#                                          ingredients  \
# 0  1/2 pęczka szparagów;1 łyżeczka masła;100 g po...
# 1  4 duże kromki chleba np. na zakwasie;1 cukinia...
# 2  1 batat;1/2 ząbka czosnku;sól, pieprz, 1/2 łyż...
# 3  10 jajek;4 łyżki majonezu;2 łyżeczki musztardy...
# 4  1 puszka białej fasolki (400 g);150 g korzenia...
#
#                                   preparation_method rating opinions_count  \
# 0  Piekarnik nagrzać do180 stopni C. Dno naczynia...   4.79             14
# 1  Cukinię umyć, odciąć końce, pokroić na ok. 0,5...   4.75              4
# 2  Piekarnik nagrzać do 210 stopni C. Batata obra...   4.71              7
# 3  Jajka ugotować na twardo (6 minut od zagotowan...    4.5              4
# 4  Fasolkę odcedzić na sitku. Selera obrać i pokr...      5              3
#
#   preparation_time vegetarian
# 0              NaN        NaN
# 1              NaN        NaN
# 2              NaN        NaN
# 3              NaN        NaN
# 4              NaN        NaN

# %%
df_recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2563 entries, 0 to 2562
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   category            2563 non-null   object
#  1   recipe_title        2563 non-null   object
#  2   ingredients         2563 non-null   object
#  3   preparation_method  2563 non-null   object
#  4   rating              2275 non-null   object
#  5   opinions_count      2275 non-null   object
#  6   preparation_time    1800 non-null   object
#  7   vegetarian          1800 non-null   object
# dtypes: object(8)
# memory usage: 160.3+ KB

# %%
df_recipes.to_csv('df_recipes.csv', index=False)

# %%
df_recipes = pd.read_csv('df_recipes.csv')

# %%
# !cp * '/content/drive/My Drive/'
# Out:
# cp: -r not specified; omitting directory 'drive'
# cp: -r not specified; omitting directory '__pycache__'
# cp: -r not specified; omitting directory 'sample_data'

# %% [markdown]
# # Wnioski
# Udało się skutecznie pobrać dane z trzech różnych źródeł stron internetowych z przepisami kulinarnymi oraz zapisaniem ich do jednego DataFrame zawierające informację takie jak tytuł, składniki, metoda przygotowania, ocena oraz liczba opinii, dzięki czemu możemy przejść do kolejnego etapu jakim jest analiza danych.
